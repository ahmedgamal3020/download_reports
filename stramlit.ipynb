# %%
import streamlit as st
import pandas as pd

# %%
df=pd.read_excel('dim_ar_notification_ab_test (1).xlsx')

# %%
df
# Out:
#      ab_pair ab_group   customer  \
# 0          1        A  CUS-02232
# 1          1        B  CUS-02211
# 2          2        A  CUS-00855
# 3          2        B  CUS-00834
# 4          3        A  CUS-00909
# ..       ...      ...        ...
# 167       86        B  CUS-00842
# 168       87        A  CUS-01318
# 169       87        B  CUS-01241
# 170       88        A  CUS-02305
# 171       88        B  CUS-02272
#
#                                      customer_name    delay_category   source
# 0              مؤسسة صحاري المتحدة لخدمات السيارات  Structural Delay  arabian
# 1                      شركة بوابة العريسة للاطارات  Structural Delay  arabian
# 2       مؤسسة عبدالرحمن ناصر سعيد ال حمدان للتجارة       Minor Delay  arabian
# 3    شركة الجزيرة المتحدة للاطارات (فرع خميس مشيط)       Minor Delay  arabian
# 4                بنشر انوار السليل لخدمات السيارات  Structural Delay  arabian
# ..                                             ...               ...      ...
# ...

# %%
st.line_chart(df,x='ab_group',y='ab_pair',)
# Out:
# 2026-04-21 10:09:02.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 10:09:02.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 10:09:02.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import logging
logging.getLogger("streamlit").setLevel(logging.ERROR)
